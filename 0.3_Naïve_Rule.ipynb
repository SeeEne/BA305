# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-1-d5df0069828e> in <cell line: 2>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#     101 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#     102   """Mount your Google Drive at the specified mountpoint path."""
# --> 103   return _mount(
#     104       mountpoint,
#     105       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     130   )
#     131   if ephemeral:
# --> 132     _message.blocking_request(
#     133         'request_auth', request={'authType': 'dfs_ephemeral'}, timeout_sec=None
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import *

# %%
df = pd.read_csv("/content/drive/My Drive/BA 305 Project/Process_data/train.csv")
df.columns
# Out:
# Index(['Unnamed: 0', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Cloud9am', 'Cloud3pm', 'Latitude', 'Longitude', 'AveragePressure',
#        'AverageTemp', 'Spring', 'Summer', 'Autumn', 'Winter', 'RainTomorrow'],
#       dtype='object')

# %%
df2 = pd.read_csv("/content/drive/My Drive/BA 305 Project/Process_data/test.csv")
df2.columns
# Out:
# Index(['Unnamed: 0', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Cloud9am', 'Cloud3pm', 'Latitude', 'Longitude', 'AveragePressure',
#        'AverageTemp', 'Spring', 'Summer', 'Autumn', 'Winter', 'RainTomorrow'],
#       dtype='object')

# %%
X_train = df.drop('RainTomorrow',axis=1).values
y_train = df['RainTomorrow'].values

# %%
X_test = df2.drop('RainTomorrow',axis=1).values
y_test = df2['RainTomorrow'].values

# %%
Count_y_train = len(y_train);
Count_y_test = len(y_test);

print("Count of entries in y_train=", Count_y_train)
print("Count of entries in y_test=", Count_y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-fa6f39ddae7d> in <cell line: 1>()
# ----> 1 Count_y_train = len(y_train);
#       2 Count_y_test = len(y_test);
#       3
#       4 print("Count of entries in y_train=", Count_y_train)
#       5 print("Count of entries in y_test=", Count_y_test)
#
# NameError: name 'y_train' is not defined

# %%
prop_y_train = round(sum(y_train)/len(y_train),2);
prop_y_test = round(sum(y_test)/len(y_test),2);

print("% of 1's in y_train=", prop_y_train)
print("% of 1's in y_test=", prop_y_test)
# Out:
# % of 1's in y_train= 0.22
# % of 1's in y_test= 0.22

# %%
y_pred = np.zeros(len(y_test))
y_pred
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-33d9777a7268> in <cell line: 1>()
# ----> 1 y_pred = np.zeros(len(y_test))
#       2 y_pred
#
# NameError: name 'np' is not defined

# %%
cm = confusion_matrix(y_test,y_pred)
cm
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-825092b1db6e> in <cell line: 1>()
# ----> 1 cm = confusion_matrix(y_test,y_pred)
#       2 cm
#
# NameError: name 'confusion_matrix' is not defined

# %%
from sklearn.metrics import accuracy_score
# Out:
# Training Accuracy: 77.86%
# Test Accuracy: 77.86%

# %%
y_pred_train = predict(X_train)
y_pred_test = predict(X_test)

print("Accuracy score on train data:", accuracy_score(y_train, y_pred_train)*100, "%")
print("Accuracy score on test data:", accuracy_score(y_test, y_pred_test)*100, "%")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-e7efba35bcce> in <cell line: 1>()
# ----> 1 y_pred_train = predict(X_train)
#       2 y_pred_test = predict(X_test)
#       3
#       4 print("Accuracy score on train data:", accuracy_score(y_train, y_pred_train)*100, "%")
#       5 print("Accuracy score on test data:", accuracy_score(y_test, y_pred_test)*100, "%")
#
# NameError: name 'predict' is not defined

# %%
# Manual computation of metrics of interest
tot = len(y_test) #total patients in test set
p = sum(y_test) #actual positives
n = tot-p #actual negatives
pp = sum(y_pred) #predicted positives
pn = tot - pp #predicted negatives

tp = cm[1,1]; # true positives
tn = cm[0,0]; # true negatives
fp = cm[0,1]; # false positives
fn = cm[1,0]; # false negatives

print('total observations =',tot, )
print('actual positives =', p, '|', 'actual negatives =', n,)
print('predicted positives =', pp, '|', 'predicted negatives =', pn)
print('true positives = ', tp, '|', 'false positives =', fp, '|', 'true negatives = ', tn, '|', 'false negatives = ', fn)

# Manual computations
m_acc = (tp + tn) / tot #accuracy
tpr = tp / p # true positive rate
fpr = fp / n # false positive rate

print('Accuracy = ', m_acc.round(2), ',', 'TPR =', tpr.round(2), ',', "FPR =", fpr.round(2))
# Out:
# total observations = 24742
# actual positives = 5478 | actual negatives = 19264
# predicted positives = 0.0 | predicted negatives = 24742.0
# true positives =  0 | false positives = 0 | true negatives =  19264 | false negatives =  5478
# Accuracy =  0.78 , TPR = 0.0 , FPR = 0.0
