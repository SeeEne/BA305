# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from plotnine import *

# %%
# df = pd.read_csv("/content/drive/My Drive/Colab Data/weatherAUS.csv")
# Xiaoyu: I change the direction to my own, please change path as need
df = pd.read_csv("/content/drive/My Drive/2023_fall/BA305/BA_305_Project/Process_data/weatherAUS.csv")
df.head()
# Out:
#          Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0  2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1  2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2  2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3  2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4  2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
#
#   WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  Humidity3pm  \
# 0           W           44.0          W  ...        71.0         22.0
# 1         WNW           44.0        NNW  ...        44.0         25.0
# 2         WSW           46.0          W  ...        38.0         30.0
# 3          NE           24.0         SE  ...        45.0         16.0
# 4           W           41.0        ENE  ...        82.0         33.0
#
#    Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  \
# ...

# %%
df = df.dropna()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 56420 entries, 6049 to 142302
# Data columns (total 23 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           56420 non-null  object
#  1   Location       56420 non-null  object
#  2   MinTemp        56420 non-null  float64
#  3   MaxTemp        56420 non-null  float64
#  4   Rainfall       56420 non-null  float64
#  5   Evaporation    56420 non-null  float64
#  6   Sunshine       56420 non-null  float64
#  7   WindGustDir    56420 non-null  object
#  8   WindGustSpeed  56420 non-null  float64
#  9   WindDir9am     56420 non-null  object
#  10  WindDir3pm     56420 non-null  object
#  11  WindSpeed9am   56420 non-null  float64
#  12  WindSpeed3pm   56420 non-null  float64
#  13  Humidity9am    56420 non-null  float64
#  14  Humidity3pm    56420 non-null  float64
#  15  Pressure9am    56420 non-null  float64
#  16  Pressure3pm    56420 non-null  float64
# ...

# %%
df[['Pressure9am', 'Pressure3pm']].corr()
# Out:
#              Pressure9am  Pressure3pm
# Pressure9am     1.000000     0.961538
# Pressure3pm     0.961538     1.000000

# %%
df['AveragePressure'] = df[['Pressure9am', 'Pressure3pm']].mean(axis=1)
df.drop(['Pressure9am', 'Pressure3pm'], axis=1, inplace=True)
df.head()
# Out:
#             Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6049  2009-01-01    Cobar     17.9     35.2       0.0         12.0      12.3
# 6050  2009-01-02    Cobar     18.4     28.9       0.0         14.8      13.0
# 6052  2009-01-04    Cobar     19.4     37.6       0.0         10.8      10.6
# 6053  2009-01-05    Cobar     21.9     38.4       0.0         11.4      12.2
# 6054  2009-01-06    Cobar     24.2     41.0       0.0         11.2       8.4
#
#      WindGustDir  WindGustSpeed WindDir9am  ... WindSpeed3pm  Humidity9am  \
# 6049         SSW           48.0        ENE  ...         20.0         20.0
# 6050           S           37.0        SSE  ...         19.0         30.0
# 6052         NNE           46.0        NNE  ...         15.0         42.0
# 6053         WNW           31.0        WNW  ...          6.0         37.0
# 6054         WNW           35.0         NW  ...         13.0         19.0
#
# ...

# %%
df[['Temp9am', 'Temp3pm','MinTemp','MaxTemp']].corr()
# Out:
#           Temp9am   Temp3pm   MinTemp   MaxTemp
# Temp9am  1.000000  0.870620  0.906295  0.893387
# Temp3pm  0.870620  1.000000  0.727222  0.984841
# MinTemp  0.906295  0.727222  1.000000  0.749687
# MaxTemp  0.893387  0.984841  0.749687  1.000000

# %%
df['AverageTemp'] = df[['Temp9am', 'Temp3pm','MinTemp','MaxTemp']].mean(axis=1)
df.drop(['Temp9am', 'Temp3pm','MinTemp','MaxTemp'], axis=1, inplace=True)
df
# Out:
#               Date Location  Rainfall  Evaporation  Sunshine WindGustDir  \
# 6049    2009-01-01    Cobar       0.0         12.0      12.3         SSW
# 6050    2009-01-02    Cobar       0.0         14.8      13.0           S
# 6052    2009-01-04    Cobar       0.0         10.8      10.6         NNE
# 6053    2009-01-05    Cobar       0.0         11.4      12.2         WNW
# 6054    2009-01-06    Cobar       0.0         11.2       8.4         WNW
# ...            ...      ...       ...          ...       ...         ...
# 142298  2017-06-20   Darwin       0.0          6.0      11.0         ENE
# 142299  2017-06-21   Darwin       0.0          7.6       8.6           E
# 142300  2017-06-22   Darwin       0.0          5.6      11.0           E
# 142301  2017-06-23   Darwin       0.0          6.2      10.6         ESE
# 142302  2017-06-24   Darwin       0.0          5.6      10.7         ENE
#
#         WindGustSpeed WindDir9am WindDir3pm  WindSpeed9am  WindSpeed3pm  \
# ...

# %%
df[["WindGustSpeed","WindSpeed9am","WindSpeed3pm"]].corr()
# so we do not need merge
# Out:
#                WindGustSpeed  WindSpeed9am  WindSpeed3pm
# WindGustSpeed       1.000000      0.608852      0.685236
# WindSpeed9am        0.608852      1.000000      0.502226
# WindSpeed3pm        0.685236      0.502226      1.000000

# %%
df[["Humidity9am", "Humidity3pm"]].corr()
# so we do not need merge
# Out:
#              Humidity9am  Humidity3pm
# Humidity9am     1.000000     0.685697
# Humidity3pm     0.685697     1.000000

# %%
df[["Cloud9am", "Cloud3pm"]].corr()
# so we do not need merge
# Out:
#           Cloud9am  Cloud3pm
# Cloud9am   1.00000   0.61438
# Cloud3pm   0.61438   1.00000

# %%
df.to_csv('2.weatherAUS_Non_impute_merge.csv')
# save data to drive
# !cp 2.weatherAUS_Non_impute_merge.csv /content/drive/MyDrive/2023_fall/BA305/BA_305_Project/Process_data

# %% [markdown]
# Now let's merge imputing data

# %%
df2 = pd.read_csv("/content/drive/My Drive/2023_fall/BA305/BA_305_Project/Process_data/1.weatherAUS_imputation.csv")
df2
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0          13.4     22.9       0.6          9.6      13.0           44.0
# 1           7.4     25.1       0.0         13.0      13.2           44.0
# 2          12.9     25.7       0.0         10.2      13.2           46.0
# 3           9.2     28.0       0.0         11.0      10.8           24.0
# 4          17.5     32.3       1.0          6.6       8.1           41.0
# ...         ...      ...       ...          ...       ...            ...
# 123705      3.5     21.8       0.0          2.2       0.0           31.0
# 123706      2.8     23.4       0.0          2.0       9.1           31.0
# 123707      3.6     25.3       0.0          1.4       8.7           22.0
# 123708      5.4     26.9       0.0          4.0       5.9           37.0
# 123709      7.8     27.0       0.0          4.0       6.4           28.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...  Temp3pm  \
# ...

# %%
df2[['Pressure9am', 'Pressure3pm']].corr()
# Out:
#              Pressure9am  Pressure3pm
# Pressure9am     1.000000     0.959676
# Pressure3pm     0.959676     1.000000

# %%
df2['AveragePressure'] = df2[['Pressure9am', 'Pressure3pm']].mean(axis=1)
df2.drop(['Pressure9am', 'Pressure3pm'], axis=1, inplace=True)
df2.head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0     13.4     22.9       0.6          9.6      13.0           44.0
# 1      7.4     25.1       0.0         13.0      13.2           44.0
# 2     12.9     25.7       0.0         10.2      13.2           46.0
# 3      9.2     28.0       0.0         11.0      10.8           24.0
# 4     17.5     32.3       1.0          6.6       8.1           41.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...   Latitude  \
# 0          20.0          24.0         71.0         22.0  ... -36.075119
# 1           4.0          22.0         44.0         25.0  ... -36.075119
# 2          19.0          26.0         38.0         30.0  ... -36.075119
# 3          11.0           9.0         45.0         16.0  ... -36.075119
# 4           7.0          20.0         82.0         33.0  ... -36.075119
#
#     Longitude        Date  Location  WindGustDir  WindDir9am WindDir3pm  \
# ...

# %%
df2[['Temp9am', 'Temp3pm','MinTemp','MaxTemp']].corr()
# Out:
#           Temp9am   Temp3pm   MinTemp   MaxTemp
# Temp9am  1.000000  0.866671  0.898399  0.891059
# Temp3pm  0.866671  1.000000  0.714223  0.983805
# MinTemp  0.898399  0.714223  1.000000  0.739111
# MaxTemp  0.891059  0.983805  0.739111  1.000000

# %%
df2['AverageMinTemp'] = df2[['Temp9am','MinTemp']].mean(axis=1)
df2['AverageMaxTemp'] = df2[['Temp3pm','MaxTemp']].mean(axis=1)

# %%
df2[['AverageMinTemp', 'AverageMaxTemp']].corr()
# Out:
#                 AverageMinTemp  AverageMaxTemp
# AverageMinTemp        1.000000        0.828183
# AverageMaxTemp        0.828183        1.000000

# %%
df2['AverageTemp'] = df2[['AverageMaxTemp', 'AverageMinTemp']].mean(axis=1)

# %%
# df2['AverageTemp'] = df2[['Temp9am', 'Temp3pm','MinTemp','MaxTemp']].mean(axis=1)
df2.drop(['Temp9am', 'Temp3pm','MinTemp','MaxTemp',"AverageMinTemp","AverageMaxTemp"], axis=1, inplace=True)
df2
# Out:
#         Rainfall  Evaporation  Sunshine  WindGustSpeed  WindSpeed9am  \
# 0            0.6          9.6      13.0           44.0          20.0
# 1            0.0         13.0      13.2           44.0           4.0
# 2            0.0         10.2      13.2           46.0          19.0
# 3            0.0         11.0      10.8           24.0          11.0
# 4            1.0          6.6       8.1           41.0           7.0
# ...          ...          ...       ...            ...           ...
# 123705       0.0          2.2       0.0           31.0          15.0
# 123706       0.0          2.0       9.1           31.0          13.0
# 123707       0.0          1.4       8.7           22.0          13.0
# 123708       0.0          4.0       5.9           37.0           9.0
# 123709       0.0          4.0       6.4           28.0          13.0
#
#         WindSpeed3pm  Humidity9am  Humidity3pm  Cloud9am  Cloud3pm  ...  \
# ...

# %%
df2[["WindGustSpeed","WindSpeed9am","WindSpeed3pm"]].corr()
# so we do not need merge
# Out:
#                WindGustSpeed  WindSpeed9am  WindSpeed3pm
# WindGustSpeed       1.000000      0.591774      0.675796
# WindSpeed9am        0.591774      1.000000      0.504546
# WindSpeed3pm        0.675796      0.504546      1.000000

# %%
df2[["Humidity9am", "Humidity3pm"]].corr()
# so we do not need merge
# Out:
#              Humidity9am  Humidity3pm
# Humidity9am     1.000000     0.681889
# Humidity3pm     0.681889     1.000000

# %%
df2[["Cloud9am", "Cloud3pm"]].corr()
# so we do not need merge
# Out:
#           Cloud9am  Cloud3pm
# Cloud9am  1.000000  0.549224
# Cloud3pm  0.549224  1.000000

# %%
df2.to_csv('2.weatherAUS_impute_merge.csv')
# save data to drive
# !cp 2.weatherAUS_impute_merge.csv /content/drive/MyDrive/2023_fall/BA305/BA_305_Project/Process_data
